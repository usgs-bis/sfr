# %% [markdown]
# This notebook works out the basic process for accessing the OBIS Areas data source from servers in Oostende, caching the data as a GeoJSON document, and setting the data up for processing in the latest iteration of our Spatial Feature Registry idea. We are currently stashing source data as files in ScienceBase Items and then kicking off a process to load them to a cloud-based PostGIS instance where we run a few synthesis operations with other spatial data and then build out one or more indexes for various purposes in ElasticSearch. The interface to these is provided via the Biogeographic Information System API.

# %%
import requests,json,geojson
from IPython.display import display
from geojson import Feature, Point, FeatureCollection

# %% [markdown]
# Ideally, we will eventually kick off all of these registration and processing steps through some kind of high level catalog or inventory based on placement and/or characteristics of the source items in ScienceBase. We should have something that is essentially watching the inventory and checking dates of update periodicity and sending items onto a message queue for processing by microservices. For now, we specify the specific items that this particular code should process and grab the item as JSON for processing here locally.

# %%
sourceItem = "https://www.sciencebase.gov/catalog/item/5aabd9a5e4b081f61aaf009b"
sourceItemMeta = requests.get(sourceItem, headers={"accept":"application/json"}).json()

# %% [markdown]
# We'll need to keep working on the information model that will help us drive this process. For now, I'm iterating through what all is necessary in order to drive this particular process, figuring out what should be stored with the item vs. what can be referenced from elsewhere. I may have to make some less than optimal choices in the near term that we'll have to clean up as we move along. I'll note those as I go.

# %%
display (sourceItemMeta)
# Out:
# {'body': 'The UNESCO-IODE-OBIS Office assembles and maintains a set of marine areas for summarizing and reporting on biodiversity and biogeographic characterization metrics. We register these areas in the Spatial Feature Registry for use in our own work and ties into the OBIS API. The spatial features in this dataset originate from MarineRegions.org and other sources and have been minimally processed spatially for use.',
#  'contacts': [{'contactType': 'organization',
#    'name': 'UNESCO-IODE-OBIS',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Data Owner'},
#   {'contactType': 'person',
#    'name': 'Pieter Provoost',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Data Owner'}],
#  'dates': [{'dateString': '2018-03-16',
#    'label': 'Validity Begins',
#    'type': 'validityBegins'}],
#  'distributionLinks': [{'files': [{'contentType': 'application/json',
#      'name': 'OBIS Areas Code List.json',
#      'size': 264,
#      'title': 'codelist'},
#     {'contentType': 'text/plain',
#      'name': 'OBISAreas.geojson',
#      'size': 61244886,
#      'title': 'load file'}],
#    'name': 'OceanBiogeograp.zip',
#    'rel': 'alternate',
#    'title': 'Download Attached Files',
#    'type': 'downloadLink',
#    'typeLabel': 'Download Link',
#    'uri': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b'}],
#  'files': [{'checksum': None,
#    'contentEncoding': None,
#    'contentType': 'application/json',
#    'dateUploaded': '2018-03-16T15:21:00Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__0b%2F36%2F8d%2F0b368d467464f385ee5eb187ee86ec5de9d6559f',
#    'imageHeight': None,
#    'imageWidth': None,
#    'name': 'OBIS Areas Code List.json',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__0b/36/8d/0b368d467464f385ee5eb187ee86ec5de9d6559f',
#    'processToken': None,
#    'processed': False,
#    's3Object': None,
#    'size': 264,
#    'title': 'codelist',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__0b%2F36%2F8d%2F0b368d467464f385ee5eb187ee86ec5de9d6559f',
#    'useForPreview': False},
#   {'checksum': None,
#    'contentEncoding': None,
#    'contentType': 'text/plain',
#    'dateUploaded': '2018-03-16T19:16:00Z',
#    'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__8f%2F8c%2Fd7%2F8f8cd75c3eb2e7196b452b276cde488cf1910fbd',
#    'imageHeight': None,
#    'imageWidth': None,
#    'name': 'OBISAreas.geojson',
#    'originalMetadata': False,
#    'pathOnDisk': '__disk__8f/8c/d7/8f8cd75c3eb2e7196b452b276cde488cf1910fbd',
#    'processToken': None,
#    'processed': False,
#    's3Object': None,
#    'size': 61244886,
#    'title': 'load file',
#    'url': 'https://www.sciencebase.gov/catalog/file/get/5aabd9a5e4b081f61aaf009b?f=__disk__8f%2F8c%2Fd7%2F8f8cd75c3eb2e7196b452b276cde488cf1910fbd',
#    'useForPreview': False}],
#  'hasChildren': False,
#  'id': '5aabd9a5e4b081f61aaf009b',
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/5aabd9a5e4b081f61aaf009b'},
#  'parentId': '55fafaf5e4b05d6c4e501b81',
#  'provenance': {'dataSource': 'Input directly',
#   'dateCreated': '2018-03-16T14:50:13Z',
#   'lastUpdated': '2018-03-16T19:16:46Z'},
#  'purpose': 'This ScienceBase Item points to a REST API end point that inventories the OBIS Areas with their identifiers and names and an OGC service that provides the geometry for the areas based on their identifiers. These access points are used with Python code referenced with a source link into the SFR data system.',
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=5aabd9a5e4b081f61aaf009b'}},
#  'summary': 'The UNESCO-IODE-OBIS Office assembles and maintains a set of marine areas for summarizing and reporting on biodiversity and biogeographic characterization metrics. We register these areas in the Spatial Feature Registry for use in our own work and ties into the OBIS API. The spatial features in this dataset originate from MarineRegions.org and other sources and have been minimally processed spatially for use.',
#  'tags': [{'name': 'Exclusive Economic Zone', 'type': 'Subject'},
#   {'name': 'Ecologically and Biologically Significant Area',
#    'type': 'Subject'},
#   {'name': 'Area Beyond National Jurisdiction', 'type': 'Subject'}],
#  'title': 'Ocean Biogeographic Information System Areas',
#  'webLinks': [{'hidden': False,
#    'rel': 'service',
#    'title': 'OBIS Areas Names and Identifiers',
#    'type': 'serviceLink',
#    'typeLabel': 'Service Link',
#    'uri': 'http://api.iobis.org/area'},
#   {'hidden': False,
#    'rel': 'service',
#    'title': 'OBIS Geoserver WFS',
#    'type': 'serviceCapabilitiesUrl',
#    'typeLabel': 'OGC Service Capabilities URL',
#    'uri': 'http://iobis.org/geoserver/OBIS/ows?service=WFS&version=1.0.0&request=GetCapabilities'}]}

# %% [markdown]
# There are several critical pieces of information that are onboard the item metadata that I pull out here as variables for processing. Right now, this is kind of stupid in that we have to have very specific a priori knowledge of what these things (links and files) are called in order to tease them out. That's not very scalable to all the other cases we want to execute and we need to think through a different way to do this. ScienceBase sort of gets toward this with its set of onboard types for files and webLinks, but the actual meaning and utility of those types is a little fuzzy and not well controlled. So, I don't think we can count on them at this time and opted to use specific titles instead.
#
# One way to approach this is to put the level of translating specific cases at something that watches ScienceBase for our registered sources and then packages messages for Kafka or whatever we end up using. We could have that be pretty specific code for a given source that puts together more standardized messages for processing. We'll have to keep thinking this through to come up with something more sustainable and scalable.

# %%
codeListURL = [f["url"] for f in sourceItemMeta["files"] if f["title"] == "codelist"][0]
inventoryAPI = [l["uri"] for l in sourceItemMeta["webLinks"] if l["title"] == "OBIS Areas Names and Identifiers"][0]
wfsGetCapabilities = [l["uri"] for l in sourceItemMeta["webLinks"] if l["title"] == "OBIS Geoserver WFS"][0]
wfsGetFeatureURLStub = wfsGetCapabilities.replace("&request=GetCapabilities","&request=GetFeature&typeName=OBIS:areas&maxFeatures=1&outputFormat=json&filter=<PropertyIsEqualTo><PropertyName>gid</PropertyName><Literal></Literal></PropertyIsEqualTo>")

# %% [markdown]
# One of the somewhat stupid things I had to do in the short term was load up a code list to the ScienceBase Item to contain stuff that this particular source needs but for which I could not come up with a reasonable external platform. In this case, the source data has a set of several types of areas that it supplies in short form (e.g., abnj = Area Beyond National Jurisdiction). There are definitions for these areas from a number of different sources, but they are not all together in one place, are not complete, and may not have the mapping we need from code to value. They are also so specific to this particular case, that it doesn't necessarily make sense to store them someplace like YAMZ where we've talked about building out definitions for things that don't already have a home. I don't think this is the best way to deal with this problem, but putting together some kind of specific code list for a given SFR registered source and storing it with that item in some way seemed to make the best immediate sense.

# %%
codeList = requests.get(codeListURL).json()
display (codeList)
# Out:
# {'Area Types': {'abnj': 'Area Beyond National Jurisdiction',
#   'ebsa': 'Ecologically and Biologically Significant Area',
#   'eez': 'Exclusive Economic Zone',
#   'obis': 'Ocean Biogeographic Information System',
#   'prot': 'Marine Protected Area'}}

# %% [markdown]
# # Get Inventory
# The first official data retrieval step in all of this is to grab up the inventory of OBIS Areas from the iOBIS API end point provided for this. It's possible that we could get everything we need for this by just looking at the OBIS:areas layer on the iOBIS Geoserver, but this simple REST service is what the OBIS guys pointed us at to work from, and we presume that it will have the most up to date and official inventory to work from.

# %%
obisAreasInventory = requests.get(inventoryAPI).json()

# %%
display (obisAreasInventory)
# Out:
# {'count': 535,
#  'lastpage': True,
#  'limit': 1000,
#  'offset': 0,
#  'results': [{'id': 309, 'name': 'The Sundarbans', 'type': 'prot'},
#   {'id': 24, 'name': 'Bosnia and Herzegovina', 'type': 'eez'},
#   {'id': 322, 'name': 'Shiretoko', 'type': 'prot'},
#   {'id': 478, 'name': 'EBSA No 2:  Ua puakaoa seamounts', 'type': 'ebsa'},
#   {'id': 371,
#    'name': 'Rivercess and Sinoe Sea Turtle Breeding Ground (Liberia)',
#    'type': 'ebsa'},
#   {'id': 127, 'name': 'Malaysia', 'type': 'eez'},
#   {'id': 339,
#    'name': 'Zone de Production Equatoriale de Thons',
#    'type': 'ebsa'},
#   {'id': 94, 'name': 'Guinea Bissau', 'type': 'eez'},
#   {'id': 313, 'name': 'High Coast / Kvarken Archipelago', 'type': 'prot'},
#   {'id': 479,
#    'name': 'Quelimane to Zuni River (Zambezi River Delta)',
#    'type': 'ebsa'},
#   {'id': 497, 'name': 'Moneron island shelf, Russia', 'type': 'ebsa'},
#   {'id': 496,
#    'name': "Canyon et trou sans fond d'Abidjan (CÂte d'Ivoire)",
#    'type': 'ebsa'},
#   {'id': 486, 'name': 'Jabuka / Pomo Pit', 'type': 'ebsa'},
#   {'id': 506, 'name': 'Fools Flat', 'type': 'ebsa'},
#   {'id': 251, 'name': 'Uruguay', 'type': 'eez'},
#   {'id': 106, 'name': 'Ireland', 'type': 'eez'},
#   {'id': 285, 'name': 'ABNJ: all', 'type': 'abnj'},
#   {'id': 120, 'name': 'Kuwait', 'type': 'eez'},
#   {'id': 264, 'name': 'Egypt: all', 'type': 'eez'},
#   {'id': 452, 'name': 'Childs Bank (South Africa)', 'type': 'ebsa'},
#   {'id': 455, 'name': 'Golfo de Fonseca', 'type': 'ebsa'},
#   {'id': 209, 'name': 'Sweden: Baltic Sea', 'type': 'eez'},
#   {'id': 276, 'name': 'Norway: all', 'type': 'eez'},
#   {'id': 110, 'name': 'Ivory Coast', 'type': 'eez'},
#   {'id': 175, 'name': 'Portugal: Madeira', 'type': 'eez'},
#   {'id': 370, 'name': 'Gulf of Guayaquil', 'type': 'ebsa'},
#   {'id': 99, 'name': 'Iceland', 'type': 'eez'},
#   {'id': 48, 'name': 'Denmark: North Sea', 'type': 'eez'},
#   {'id': 28, 'name': 'Bulgaria', 'type': 'eez'},
#   {'id': 262, 'name': 'Denmark: all', 'type': 'eez'},
#   {'id': 362, 'name': 'EBSA No. 8: New Britain Trench Region', 'type': 'ebsa'},
#   {'id': 204, 'name': 'Spain: Mediterranean Sea', 'type': 'eez'},
#   {'id': 151, 'name': 'New Zealand', 'type': 'eez'},
#   {'id': 384,
#    'name': 'North Western Mediterranean Benthic Ecosystem',
#    'type': 'ebsa'},
#   {'id': 162, 'name': 'Norway: Bouvet Island', 'type': 'eez'},
#   {'id': 253, 'name': 'Venezuela', 'type': 'eez'},
#   {'id': 30, 'name': 'Cameroon', 'type': 'eez'},
#   {'id': 399,
#    'name': 'Wrangel-Herald Shallow and Ratmanov Gyre',
#    'type': 'ebsa'},
#   {'id': 119, 'name': 'Kiribati', 'type': 'eez'},
#   {'id': 356,
#    'name': 'EBSA No. 19: Clipperton Fracture Zone petrel foraging area',
#    'type': 'ebsa'},
#   {'id': 299, 'name': 'Heard and McDonald Islands', 'type': 'prot'},
#   {'id': 95, 'name': 'Guyana', 'type': 'eez'},
#   {'id': 270, 'name': 'Israel: all', 'type': 'eez'},
#   {'id': 122, 'name': 'Lebanon', 'type': 'eez'},
#   {'id': 437,
#    'name': 'Commander Islands shelf and slope, Russia',
#    'type': 'ebsa'},
#   {'id': 62, 'name': 'Finland', 'type': 'eez'},
#   {'id': 514, 'name': 'Monts sous-marins Cayar (SÅnÅgal)', 'type': 'ebsa'},
#   {'id': 329, 'name': 'Papahanaumokuakea', 'type': 'prot'},
#   {'id': 518, 'name': 'Tromelin Island', 'type': 'ebsa'},
#   {'id': 268, 'name': 'Honduras: all', 'type': 'eez'},
#   {'id': 531, 'name': 'Rusky', 'type': 'ebsa'},
#   {'id': 310, 'name': 'Cocos Island National Park', 'type': 'prot'},
#   {'id': 214, 'name': 'Togo', 'type': 'eez'},
#   {'id': 454,
#    'name': 'South East Kamchatka coastal waters, Russia',
#    'type': 'ebsa'},
#   {'id': 180, 'name': 'Russia: Black Sea', 'type': 'eez'},
#   {'id': 397, 'name': 'Walters Shoal', 'type': 'ebsa'},
#   {'id': 160, 'name': 'North Pacific', 'type': 'abnj'},
#   {'id': 390, 'name': 'Cayos Miskitos', 'type': 'ebsa'},
#   {'id': 101, 'name': 'India: Andaman and Nicobar', 'type': 'eez'},
#   {'id': 20, 'name': 'Barbados', 'type': 'eez'},
#   {'id': 330, 'name': 'Ogasawara Islands', 'type': 'prot'},
#   {'id': 82, 'name': 'France: Wallis and Futuna', 'type': 'eez'},
#   {'id': 439, 'name': 'Rufiji - Mafia- Kilwa', 'type': 'ebsa'},
#   {'id': 25, 'name': 'Brazil', 'type': 'eez'},
#   {'id': 359, 'name': 'Galapagos', 'type': 'ebsa'},
#   {'id': 213, 'name': 'Thailand', 'type': 'eez'},
#   {'id': 26, 'name': 'Brazil: Trindade', 'type': 'eez'},
#   {'id': 137, 'name': 'Montenegro', 'type': 'eez'},
#   {'id': 117, 'name': 'Jordan', 'type': 'eez'},
#   {'id': 438, 'name': 'Offshore of Port Elizabeth', 'type': 'ebsa'},
#   {'id': 265, 'name': 'France: all', 'type': 'eez'},
#   {'id': 185, 'name': 'Saint Vincent and the Grenadines', 'type': 'eez'},
#   {'id': 405, 'name': 'Central Aegean Sea', 'type': 'ebsa'},
#   {'id': 379,
#    'name': 'EBSA No 17: Central Louisville Seamount Chain',
#    'type': 'ebsa'},
#   {'id': 292,
#    'name': 'Gulf of Porto: Calanche of Piana, Gulf of Girolata, Scandola Reserve',
#    'type': 'prot'},
#   {'id': 487,
#    'name': 'EBSA No. 10:  Rarotonga Outer Reef Slopes (80-300m depth)',
#    'type': 'ebsa'},
#   {'id': 168, 'name': 'Panama: North Pacific', 'type': 'eez'},
#   {'id': 136, 'name': 'Monaco', 'type': 'eez'},
#   {'id': 196, 'name': 'South Africa: Indian Ocean', 'type': 'eez'},
#   {'id': 218, 'name': 'Turkey', 'type': 'eez'},
#   {'id': 373, 'name': 'EBSA No 23: Manihiki Plateau', 'type': 'ebsa'},
#   {'id': 349, 'name': 'Corridor Marino', 'type': 'ebsa'},
#   {'id': 363, 'name': 'Equatorial Front and Carnegie Ridge', 'type': 'ebsa'},
#   {'id': 341, 'name': 'Atlantic Equatorial Fracture Zone', 'type': 'ebsa'},
#   {'id': 238, 'name': 'United States: Alaska: Arctic Ocean', 'type': 'eez'},
#   {'id': 27, 'name': 'Brunei', 'type': 'eez'},
#   {'id': 286, 'name': 'OBIS', 'type': 'obis'},
#   {'id': 230, 'name': 'United Kingdom: Guernsey', 'type': 'eez'},
#   {'id': 409,
#    'name': 'Slopes of the Flemish Cap and Grand Bank',
#    'type': 'ebsa'},
#   {'id': 89, 'name': 'Greece', 'type': 'eez'},
#   {'id': 302, 'name': 'Komodo National Park', 'type': 'prot'},
#   {'id': 269, 'name': 'India: all', 'type': 'eez'},
#   {'id': 414, 'name': 'Saya de Malha Bank', 'type': 'ebsa'},
#   {'id': 449,
#    'name': 'Coastal lagoons and Islands off Baja California and Offshore Waters Complex, Mexico',
#    'type': 'ebsa'},
#   {'id': 446, 'name': 'Agulhas Bank Nursery Area', 'type': 'ebsa'},
#   {'id': 155, 'name': 'Nicaragua: North Atlantic', 'type': 'eez'},
#   {'id': 417, 'name': 'Browns Bank (South Africa)', 'type': 'ebsa'},
#   {'id': 434, 'name': 'South Adriatic Ionian Strait', 'type': 'ebsa'},
#   {'id': 149, 'name': 'Netherlands: Sint-Eustasius', 'type': 'eez'},
#   {'id': 93, 'name': 'Guinea', 'type': 'eez'},
#   {'id': 389, 'name': 'Juan Fernandez Seamounts', 'type': 'ebsa'},
#   {'id': 307, 'name': 'Gough and Inaccessible Islands', 'type': 'prot'},
#   {'id': 97, 'name': 'Honduras: North Atlantic', 'type': 'eez'},
#   {'id': 249,
#    'name': 'United States: Puerto Rico and Virgin Islands of the United States',
#    'type': 'eez'},
#   {'id': 126, 'name': 'Madagascar', 'type': 'eez'},
#   {'id': 135, 'name': 'Micronesia', 'type': 'eez'},
#   {'id': 520, 'name': 'Moheli Marine Park', 'type': 'ebsa'},
#   {'id': 504,
#    'name': 'Plateau continental Nord-Ouest (Congo)',
#    'type': 'ebsa'},
#   {'id': 382, 'name': 'Costa Rica Dome', 'type': 'ebsa'},
#   {'id': 284, 'name': 'United States: all', 'type': 'eez'},
#   {'id': 335, 'name': 'Agulhas Front', 'type': 'ebsa'},
#   {'id': 205, 'name': 'Spain: North Atlantic', 'type': 'eez'},
#   {'id': 197, 'name': 'South Africa: Prince Edward Islands', 'type': 'eez'},
#   {'id': 187, 'name': 'Sao Tome and Principe', 'type': 'eez'},
#   {'id': 447,
#    'name': 'EBSA No. 14: Vatu-i-Ra/Lomaiviti, Fiji',
#    'type': 'ebsa'},
#   {'id': 114, 'name': 'Joint Regime: Colombia - Jamaica', 'type': 'eez'},
#   {'id': 351, 'name': 'Walvis Ridge', 'type': 'ebsa'},
#   {'id': 191, 'name': 'Sierra Leone', 'type': 'eez'},
#   {'id': 156, 'name': 'Nicaragua: North Pacific', 'type': 'eez'},
#   {'id': 295, 'name': 'Sundarbans National Park', 'type': 'prot'},
#   {'id': 11, 'name': 'Australia - Papua New Guinea', 'type': 'eez'},
#   {'id': 386, 'name': 'East and South Chukotka coast, Russia', 'type': 'ebsa'},
#   {'id': 450,
#    'name': 'Cape Canyon and Surrounds (South Africa)',
#    'type': 'ebsa'},
#   {'id': 42, 'name': 'Croatia', 'type': 'eez'},
#   {'id': 334,
#    'name': 'EBSA No.16: Equatorial High-Productivity Zone',
#    'type': 'ebsa'},
#   {'id': 203, 'name': 'Spain: Canary Islands', 'type': 'eez'},
#   {'id': 228, 'name': 'United Kingdom: Cayman Islands', 'type': 'eez'},
#   {'id': 194, 'name': 'Solomon Islands', 'type': 'eez'},
#   {'id': 511, 'name': 'Bouche du Roi-Togbin', 'type': 'ebsa'},
#   {'id': 534,
#    'name': 'Praia das conchas e lagoa Azul (Sao TomÅ)',
#    'type': 'ebsa'},
#   {'id': 252, 'name': 'Vanuatu', 'type': 'eez'},
#   {'id': 430, 'name': 'Labrador Sea Deep Convection Area', 'type': 'ebsa'},
#   {'id': 523, 'name': 'Embouchure du Rio Pongo (Guinea)', 'type': 'ebsa'},
#   {'id': 39, 'name': 'Comoro Islands', 'type': 'eez'},
#   {'id': 316, 'name': 'Península Valdés', 'type': 'prot'},
#   {'id': 132, 'name': 'Mauritius', 'type': 'eez'},
#   {'id': 336, 'name': 'Sargasso Sea', 'type': 'ebsa'},
#   {'id': 502,
#    'name': 'Zone marine et CÂtiÉre de Mayumba (Gabon)',
#    'type': 'ebsa'},
#   {'id': 526, 'name': 'Watamu Area', 'type': 'ebsa'},
#   {'id': 508, 'name': 'Embouchure de la Casamance (SÅnÅgal)', 'type': 'ebsa'},
#   {'id': 489,
#    'name': 'Incomati River to Ponta do Ouro (southern Mozambique)',
#    'type': 'ebsa'},
#   {'id': 378, 'name': 'EBSA No 11:  Samoan Archipelago', 'type': 'ebsa'},
#   {'id': 131, 'name': 'Mauritania', 'type': 'eez'},
#   {'id': 369,
#    'name': 'Orange Shelf Edge (Namibia/South Africa)',
#    'type': 'ebsa'},
#   {'id': 178, 'name': 'Russia: Arctic Ocean', 'type': 'eez'},
#   {'id': 67, 'name': 'France: French Guiana', 'type': 'eez'},
#   {'id': 457, 'name': 'Corn Island', 'type': 'ebsa'},
#   {'id': 471, 'name': 'Protea Banks and sardine route', 'type': 'ebsa'},
#   {'id': 255, 'name': 'Yemen', 'type': 'eez'},
#   {'id': 464, 'name': 'Save River to San Sebastian', 'type': 'ebsa'},
#   {'id': 241, 'name': 'United States: Hawaii', 'type': 'eez'},
#   {'id': 324, 'name': 'Malpelo Fauna and Flora Sanctuary', 'type': 'prot'},
#   {'id': 357, 'name': 'Southern Brazilian Sea', 'type': 'ebsa'},
#   {'id': 352, 'name': 'EBSA No. 15: South Tasman Sea', 'type': 'ebsa'},
#   {'id': 465, 'name': 'East Levantine Canyons (ELCA)', 'type': 'ebsa'},
#   {'id': 325, 'name': 'Socotra Archipelago', 'type': 'prot'},
#   {'id': 17, 'name': 'Bahamas', 'type': 'eez'},
#   {'id': 395,
#    'name': 'Banks of Northern Brazil and Fernando de Noronha',
#    'type': 'ebsa'},
#   {'id': 142, 'name': 'Namibia', 'type': 'eez'},
#   {'id': 66, 'name': 'France: Crozet Islands', 'type': 'eez'},
#   {'id': 224, 'name': 'United Kingdom: Ascension', 'type': 'eez'},
#   {'id': 477,
#    'name': 'Morrumbene to Zavora bay (Southern Mozambique)',
#    'type': 'ebsa'},
#   {'id': 50, 'name': 'Dominica', 'type': 'eez'},
#   {'id': 33, 'name': 'Canada: North Pacific', 'type': 'eez'},
#   {'id': 512, 'name': 'Atlantis Seamount', 'type': 'ebsa'},
#   {'id': 513, 'name': 'Complexe de Santa Luzia (Cape Verde)', 'type': 'ebsa'},
#   {'id': 442, 'name': 'Le Golfe de GabÉs', 'type': 'ebsa'},
#   {'id': 109, 'name': 'Italy', 'type': 'eez'},
#   {'id': 57, 'name': 'El Salvador', 'type': 'eez'},
#   {'id': 51, 'name': 'Dominican Republic', 'type': 'eez'},
#   {'id': 239, 'name': 'United States: Alaska: North Pacific', 'type': 'eez'},
#   {'id': 31, 'name': 'Canada: Arctic Ocean', 'type': 'eez'},
#   {'id': 288,
#    'name': 'Kluane / Wrangell-St Elias / Glacier Bay / Tatshenshini-Alsek',
#    'type': 'prot'},
#   {'id': 76, 'name': 'France: Mediterranean Sea', 'type': 'eez'},
#   {'id': 406, 'name': 'Hellenic Trench', 'type': 'ebsa'},
#   {'id': 524, 'name': 'Namibia Islands (Namibia)', 'type': 'ebsa'},
#   {'id': 69, 'name': 'France: Glorioso Islands', 'type': 'eez'},
#   {'id': 460, 'name': 'Orphan Knoll', 'type': 'ebsa'},
#   {'id': 529,
#    'name': 'Zone cÊtiÉre et marine de Mouanda (RDC)',
#    'type': 'ebsa'},
#   {'id': 441, 'name': 'Agulhas slope and seamounts', 'type': 'ebsa'},
#   {'id': 385,
#    'name': 'White Shark Cafe / Shark Offshore Feeding Area',
#    'type': 'ebsa'},
#   {'id': 393, 'name': 'EBSA No. 26: Tongan Archipelago', 'type': 'ebsa'},
#   {'id': 34, 'name': 'Cape Verde', 'type': 'eez'},
#   {'id': 505, 'name': 'Namaqua Coastal Area (South Africa)', 'type': 'ebsa'},
#   {'id': 219, 'name': 'Tuvalu', 'type': 'eez'},
#   {'id': 81, 'name': 'France: Saint Pierre and Miquelon', 'type': 'eez'},
#   {'id': 273, 'name': 'Netherlands: all', 'type': 'eez'},
#   {'id': 12, 'name': 'Australia: Christmas Island', 'type': 'eez'},
#   {'id': 296, 'name': "Banc d'Arguin National Park", 'type': 'prot'},
#   {'id': 521, 'name': 'Sri Lankan side of Gulf of Mannar', 'type': 'ebsa'},
#   {'id': 282, 'name': 'Sweden: all', 'type': 'eez'},
#   {'id': 79, 'name': 'France: Northern Saint-Martin', 'type': 'eez'},
#   {'id': 10, 'name': 'Australia - Indonesia', 'type': 'eez'},
#   {'id': 321,
#    'name': 'Islands and Protected Areas of the Gulf of California',
#    'type': 'prot'},
#   {'id': 428, 'name': 'Zone du Large et de la ZEE', 'type': 'ebsa'},
#   {'id': 90, 'name': 'Grenada', 'type': 'eez'},
#   {'id': 481, 'name': 'Pemba-Shimoni-Kisite', 'type': 'ebsa'},
#   {'id': 134, 'name': 'Mexico: North Pacific', 'type': 'eez'},
#   {'id': 18, 'name': 'Bahrain', 'type': 'eez'},
#   {'id': 139, 'name': 'Morocco: North Atlantic', 'type': 'eez'},
#   {'id': 59, 'name': 'Eritrea', 'type': 'eez'},
#   {'id': 2, 'name': 'Algeria', 'type': 'eez'},
#   {'id': 354, 'name': 'Northern Mozambique Channel', 'type': 'ebsa'},
#   {'id': 146, 'name': 'Netherlands: Bonaire', 'type': 'eez'},
#   {'id': 192, 'name': 'Singapore', 'type': 'eez'},
#   {'id': 143, 'name': 'Nauru', 'type': 'eez'},
#   {'id': 338, 'name': 'Subtropical Convergence Zone', 'type': 'ebsa'},
#   {'id': 98, 'name': 'Honduras: North Pacific', 'type': 'eez'},
#   {'id': 424,
#    'name': 'Yamskie Islands and western Shelikhov Bay, Russia',
#    'type': 'ebsa'},
#   {'id': 381,
#    'name': 'South-eastern Barents Sea (the Pechora Sea)',
#    'type': 'ebsa'},
#   {'id': 193, 'name': 'Slovenia', 'type': 'eez'},
#   {'id': 271, 'name': 'Mexico: all', 'type': 'eez'},
#   {'id': 408,
#    'name': 'Southern Madagascar (Part of Mozambique Channel)',
#    'type': 'ebsa'},
#   {'id': 466, 'name': 'Sipacate ? Las Lisas', 'type': 'ebsa'},
#   {'id': 243, 'name': 'United States: Jarvis Island', 'type': 'eez'},
#   {'id': 167, 'name': 'Panama: North Atlantic', 'type': 'eez'},
#   {'id': 250, 'name': 'United States: Wake Island', 'type': 'eez'},
#   {'id': 350,
#    'name': 'Zone de Convergence des Courants de GuinÅe-Canarie',
#    'type': 'ebsa'},
#   {'id': 315, 'name': 'Area de Conservación Guanacaste', 'type': 'prot'},
#   {'id': 463,
#    'name': 'EBSA No. 24: Niue Island and Beveridge reef',
#    'type': 'ebsa'},
#   {'id': 116,
#    'name': 'Joint Regime: Nigeria - Sao Tome and Principe',
#    'type': 'eez'},
#   {'id': 64, 'name': 'France: Bassas da India', 'type': 'eez'},
#   {'id': 235,
#    'name': 'United Kingdom: South Georgia and the South Sandwich Islands',
#    'type': 'eez'},
#   {'id': 394, 'name': 'West Wind Drift Convergence Region', 'type': 'ebsa'},
#   {'id': 248, 'name': 'United States: Palmyra Atoll', 'type': 'eez'},
#   {'id': 387,
#    'name': 'EBSA No. 20: Northern Lord Howe Ridge petrel foraging area',
#    'type': 'ebsa'},
#   {'id': 84, 'name': 'Gambia', 'type': 'eez'},
#   {'id': 267, 'name': 'Guatemala: all', 'type': 'eez'},
#   {'id': 138, 'name': 'Morocco: Mediterranean Sea', 'type': 'eez'},
#   {'id': 145, 'name': 'Netherlands: Aruba', 'type': 'eez'},
#   {'id': 501, 'name': 'Canyon de Cayar (SÅnÅgal)', 'type': 'ebsa'},
#   {'id': 207, 'name': 'Sudan', 'type': 'eez'},
#   {'id': 458, 'name': 'Iles Boavista (Cape Verde)', 'type': 'ebsa'},
#   {'id': 198, 'name': 'South Africa: South Atlantic', 'type': 'eez'},
#   {'id': 74, 'name': 'France: Kerguelen Islands', 'type': 'eez'},
#   {'id': 104, 'name': 'Iran', 'type': 'eez'},
#   {'id': 413,
#    'name': 'Northeastern Brazilian Shelf-Edge Zone',
#    'type': 'ebsa'},
#   {'id': 163, 'name': 'Norway: Jan Mayen', 'type': 'eez'},
#   {'id': 418, 'name': 'NorthernHCSUpwelling', 'type': 'ebsa'},
#   {'id': 102, 'name': 'Indian Ocean', 'type': 'abnj'},
#   {'id': 509, 'name': 'Alijos Islands, Mexico', 'type': 'ebsa'},
#   {'id': 6, 'name': 'Antigua and Barbuda', 'type': 'eez'},
#   {'id': 246, 'name': 'United States: North Pacific', 'type': 'eez'},
#   {'id': 71, 'name': 'France: Ile Europa', 'type': 'eez'},
#   {'id': 533, 'name': 'Akamas and Chrysochou Bay', 'type': 'ebsa'},
#   {'id': 29, 'name': 'Cambodia', 'type': 'eez'},
#   {'id': 488,
#    'name': 'Coral Seamount and fracture zone feature',
#    'type': 'ebsa'},
#   {'id': 159, 'name': 'North Korea', 'type': 'eez'},
#   {'id': 343, 'name': 'Central Indian Basin', 'type': 'ebsa'},
#   {'id': 72, 'name': 'France: Ile Tromelin', 'type': 'eez'},
#   {'id': 41, 'name': 'Costa Rica: North Pacific', 'type': 'eez'},
#   {'id': 234, 'name': 'United Kingdom: Saint Helena', 'type': 'eez'},
#   {'id': 186, 'name': 'Samoa', 'type': 'eez'},
#   {'id': 516, 'name': 'Tortuguero ? Barra del Colorado', 'type': 'ebsa'},
#   {'id': 177, 'name': 'Romania', 'type': 'eez'},
#   {'id': 141, 'name': 'Myanmar', 'type': 'eez'},
#   {'id': 402,
#    'name': 'EBSA No. 9: New Hebrides Trench Region',
#    'type': 'ebsa'},
#   {'id': 467, 'name': 'Kunene - Tigress (Angola/Namibia)', 'type': 'ebsa'},
#   {'id': 346,
#    'name': 'Focal foraging areas for Hawaiian albatrosses during egg-laying and incubation',
#    'type': 'ebsa'},
#   {'id': 171, 'name': 'Philippines', 'type': 'eez'},
#   {'id': 480,
#    'name': 'Talud Continental Superior del Magdalena',
#    'type': 'ebsa'},
#   {'id': 227, 'name': 'United Kingdom: British Virgin Islands', 'type': 'eez'},
#   {'id': 337, 'name': 'Equatorial Productivity Zone', 'type': 'ebsa'},
#   {'id': 247,
#    'name': 'United States: Northern Mariana Islands and Guam',
#    'type': 'eez'},
#   {'id': 380, 'name': 'Mahe, Alphonse and Amirantes Plateau', 'type': 'ebsa'},
#   {'id': 280, 'name': 'South Africa: all', 'type': 'eez'},
#   {'id': 347,
#    'name': 'Prince Edward Islands , Del Cano Rise and Crozet Islands',
#    'type': 'ebsa'},
#   {'id': 311, 'name': 'East Rennell', 'type': 'prot'},
#   {'id': 410,
#    'name': 'Cobb-Eickelberg Seamount Chain/ Northeast Pacific Rim east of Aleutians to California  -- Gulf of Alaska area',
#    'type': 'ebsa'},
#   {'id': 517,
#    'name': 'Zone marine transfrontalier Togo-BÅnin',
#    'type': 'ebsa'},
#   {'id': 242,
#    'name': 'United States: Howland Island and Baker Island',
#    'type': 'eez'},
#   {'id': 297, 'name': 'Whale Sanctuary of El Vizcaino', 'type': 'prot'},
#   {'id': 419, 'name': 'SouthernHCSUpwelling', 'type': 'ebsa'},
#   {'id': 459,
#    'name': 'Parcel do Manuel Luiz e Banco do àlvaro',
#    'type': 'ebsa'},
#   {'id': 314, 'name': 'iSimangaliso Wetland Park', 'type': 'prot'},
#   {'id': 190, 'name': 'Seychelles', 'type': 'eez'},
#   {'id': 16, 'name': 'Australia: Norfolk Island', 'type': 'eez'},
#   {'id': 444, 'name': 'Delagoa shelf edge, canyons and slope', 'type': 'ebsa'},
#   {'id': 391, 'name': 'Clipperton Atoll', 'type': 'ebsa'},
#   {'id': 274, 'name': 'New Zealand: all', 'type': 'eez'},
#   {'id': 54, 'name': 'Ecuador: Galapagos Islands', 'type': 'eez'},
#   {'id': 400, 'name': 'New England and Corner Rise Seamounts', 'type': 'ebsa'},
#   {'id': 342, 'name': 'Multi-Year Ice of the Arctic Ocean', 'type': 'ebsa'},
#   {'id': 473, 'name': 'EBSA No. 7:  Monowai Seamount', 'type': 'ebsa'},
#   {'id': 320,
#    'name': 'Coiba National Park and its Special Zone of Marine Protection',
#    'type': 'prot'},
#   {'id': 426, 'name': 'Hydrothermal Vent Fields', 'type': 'ebsa'},
#   {'id': 103, 'name': 'Indonesia', 'type': 'eez'},
#   {'id': 412, 'name': 'Nile Delta Fan', 'type': 'ebsa'},
#   {'id': 47, 'name': 'Denmark: Greenland', 'type': 'eez'},
#   {'id': 115, 'name': 'Joint Regime: Japan - Korea', 'type': 'eez'},
#   {'id': 525, 'name': 'Namaqua Fossil Forest (South Africa)', 'type': 'ebsa'},
#   {'id': 148, 'name': 'Netherlands: Saba', 'type': 'eez'},
#   {'id': 236, 'name': 'United Kingdom: Tristan da Cunha', 'type': 'eez'},
#   {'id': 208, 'name': 'Suriname', 'type': 'eez'},
#   {'id': 323,
#    'name': 'West Norwegian Fjords – Geirangerfjord and Nærøyfjord',
#    'type': 'prot'},
#   {'id': 211, 'name': 'Syria', 'type': 'eez'},
#   {'id': 46, 'name': 'Denmark: Faeroe Islands', 'type': 'eez'},
#   {'id': 368,
#    'name': 'EBSA No. 13: South of Tuvalu/Wallis & Fortuna/North of Fiji Plateau',
#    'type': 'ebsa'},
#   {'id': 294, 'name': "Sian Ka'an", 'type': 'prot'},
#   {'id': 83, 'name': 'Gabon', 'type': 'eez'},
#   {'id': 36, 'name': 'Chile: Easter Island', 'type': 'eez'},
#   {'id': 174, 'name': 'Portugal: Azores', 'type': 'eez'},
#   {'id': 15, 'name': 'Australia: Macquarie Island', 'type': 'eez'},
#   {'id': 304,
#    'name': 'Puerto-Princesa Subterranean River National Park',
#    'type': 'prot'},
#   {'id': 361, 'name': 'Benguela Upwelling System', 'type': 'ebsa'},
#   {'id': 77, 'name': 'France: New Caledonia', 'type': 'eez'},
#   {'id': 125, 'name': 'Lithuania', 'type': 'eez'},
#   {'id': 140, 'name': 'Mozambique', 'type': 'eez'},
#   {'id': 451,
#    'name': 'Pemba Bay - Mtwara (part of the Mozambique Channel)',
#    'type': 'ebsa'},
#   {'id': 474,
#    'name': "RÅcifs coralliens d'eau froide au large de Nouakchott  (Mauritanie)",
#    'type': 'ebsa'},
#   {'id': 4, 'name': 'Antarctica: South Atlantic', 'type': 'eez'},
#   {'id': 407, 'name': 'West Kamchatka shelf, Russia', 'type': 'ebsa'},
#   {'id': 153, 'name': 'New Zealand: Niue', 'type': 'eez'},
#   {'id': 257, 'name': 'Australia: all', 'type': 'eez'},
#   {'id': 200, 'name': 'South Korea', 'type': 'eez'},
#   {'id': 233, 'name': 'United Kingdom: Pitcairn', 'type': 'eez'},
#   {'id': 111, 'name': 'Jamaica', 'type': 'eez'},
#   {'id': 206, 'name': 'Sri Lanka', 'type': 'eez'},
#   {'id': 220, 'name': 'Ukraine', 'type': 'eez'},
#   {'id': 73, 'name': 'France: Juan de Nova Island', 'type': 'eez'},
#   {'id': 56, 'name': 'Egypt: Red Sea', 'type': 'eez'},
#   {'id': 40, 'name': 'Costa Rica: North Atlantic', 'type': 'eez'},
#   {'id': 182, 'name': 'RÃ©publique du Congo', 'type': 'eez'},
#   {'id': 355,
#    'name': 'EBSA No. 4:  Remetau group: SW Caroline Islands and northern New Guinea EBSA',
#    'type': 'ebsa'},
#   {'id': 53, 'name': 'Ecuador', 'type': 'eez'},
#   {'id': 222, 'name': 'United Kingdom', 'type': 'eez'},
#   {'id': 277, 'name': 'Panama: all', 'type': 'eez'},
#   {'id': 275, 'name': 'Nicaragua: all', 'type': 'eez'},
#   {'id': 261, 'name': 'Costa Rica: all', 'type': 'eez'},
#   {'id': 123, 'name': 'Liberia', 'type': 'eez'},
#   {'id': 92, 'name': 'Guatemala: North Pacific', 'type': 'eez'},
#   {'id': 528, 'name': 'Coronado Islands, Mexico', 'type': 'ebsa'},
#   {'id': 23, 'name': 'Benin', 'type': 'eez'},
#   {'id': 348, 'name': 'Amazonina-Orinoco Influenced Zone', 'type': 'ebsa'},
#   {'id': 44, 'name': 'Cyprus', 'type': 'eez'},
#   {'id': 332, 'name': 'Rock Islands Southern Lagoon', 'type': 'prot'},
#   {'id': 468, 'name': 'Peter the Great Bay, Russia', 'type': 'ebsa'},
#   {'id': 333,
#    'name': 'North Pacific Transition Zone and bordering currents',
#    'type': 'ebsa'},
#   {'id': 58, 'name': 'Equatorial Guinea', 'type': 'eez'},
#   {'id': 1, 'name': 'Albania', 'type': 'eez'},
#   {'id': 484,
#    'name': 'SystÉme du û\xa0Canyon de Timiris\xa0ý de Mauritanie',
#    'type': 'ebsa'},
#   {'id': 189, 'name': 'Senegal', 'type': 'eez'},
#   {'id': 290, 'name': 'Great Barrier Reef', 'type': 'prot'},
#   {'id': 404, 'name': 'Gulf of Sirte', 'type': 'ebsa'},
#   {'id': 507, 'name': "Habitat Cotier et marin d'Agbodrafo", 'type': 'ebsa'},
#   {'id': 485,
#    'name': "Cellule de l'Upwelling permanent dans la zone Nord de Mauritanie",
#    'type': 'ebsa'},
#   {'id': 237,
#    'name': 'United Kingdom: Turks and Caicos Islands',
#    'type': 'eez'},
#   {'id': 364, 'name': 'EBSA No. 1.:   Phoenix Islands', 'type': 'ebsa'},
#   {'id': 372,
#    'name': 'Emperor Seamount Chain and Northern Hawaiian Ridge',
#    'type': 'ebsa'},
#   {'id': 376, 'name': 'Mesoamerian Reef', 'type': 'ebsa'},
#   {'id': 226,
#    'name': 'United Kingdom: British Indian Ocean Territory',
#    'type': 'eez'},
#   {'id': 86, 'name': 'Germany: Baltic Sea', 'type': 'eez'},
#   {'id': 500, 'name': 'Guadalupe Island, Mexico', 'type': 'ebsa'},
#   {'id': 49, 'name': 'Djibouti', 'type': 'eez'},
#   {'id': 13, 'name': 'Australia: Cocos Islands', 'type': 'eez'},
#   {'id': 22, 'name': 'Belize', 'type': 'eez'},
#   {'id': 515, 'name': 'Cahuita ? Gandoca', 'type': 'ebsa'},
#   {'id': 360, 'name': 'Middle of Nowhere', 'type': 'ebsa'},
#   {'id': 91, 'name': 'Guatemala: North Atlantic', 'type': 'eez'},
#   {'id': 70, 'name': 'France: Guadeloupe and Martinique', 'type': 'eez'},
#   {'id': 45, 'name': 'Denmark: Baltic Sea', 'type': 'eez'},
#   {'id': 225, 'name': 'United Kingdom: Bermuda', 'type': 'eez'},
#   {'id': 199, 'name': 'South Atlantic', 'type': 'abnj'},
#   {'id': 433,
#    'name': 'Baixo Pinda - Pebane (Primeiras and Segundas Islands)',
#    'type': 'ebsa'},
#   {'id': 303, 'name': 'Macquarie Island', 'type': 'prot'},
#   {'id': 293, 'name': 'St Kilda', 'type': 'prot'},
#   {'id': 495,
#    'name': 'Nord Ouest de Santa Antao (Cape Verde)',
#    'type': 'ebsa'},
#   {'id': 60, 'name': 'Estonia', 'type': 'eez'},
#   {'id': 365,
#    'name': 'Abrolhos bank and VitÆria-Trindade Chain',
#    'type': 'ebsa'},
#   {'id': 532,
#    'name': "Route des Crevettes et des Sardines de Tabou--Assinie (CÂte d'Ivoire)",
#    'type': 'ebsa'},
#   {'id': 165, 'name': 'Pakistan', 'type': 'eez'},
#   {'id': 287, 'name': 'Galápagos Islands', 'type': 'prot'},
#   {'id': 422, 'name': 'North East Levantine Sea', 'type': 'ebsa'},
#   {'id': 327, 'name': 'The Wadden Sea', 'type': 'prot'},
#   {'id': 105, 'name': 'Iraq', 'type': 'eez'},
#   {'id': 21, 'name': 'Belgium', 'type': 'eez'},
#   {'id': 152, 'name': 'New Zealand: Cook Islands', 'type': 'eez'},
#   {'id': 75, 'name': 'France: Mayotte', 'type': 'eez'},
#   {'id': 469,
#    'name': "Canyon et montagne de Tabou (CÂte d'Ivoire)",
#    'type': 'ebsa'},
#   {'id': 475, 'name': 'Tanga Coelacanth Marine Park', 'type': 'ebsa'},
#   {'id': 124, 'name': 'Libya', 'type': 'eez'},
#   {'id': 401,
#    'name': 'Eastern shelf of Sakhalin island, Russia',
#    'type': 'ebsa'},
#   {'id': 281, 'name': 'Spain: all', 'type': 'eez'},
#   {'id': 5, 'name': 'Antarctica: Southern Ocean', 'type': 'eez'},
#   {'id': 462, 'name': 'Juan de Fuca Ridge Hydrothermal Vents', 'type': 'ebsa'},
#   {'id': 510, 'name': 'Talud Continental Superior del SinÇ', 'type': 'ebsa'},
#   {'id': 229, 'name': 'United Kingdom: Gibraltar', 'type': 'eez'},
#   {'id': 301, 'name': 'Ujung Kulon National Park', 'type': 'prot'},
#   {'id': 245, 'name': 'United States: North Atlantic', 'type': 'eez'},
#   {'id': 461, 'name': 'Lamu-Kiunga area', 'type': 'ebsa'},
#   {'id': 415, 'name': 'White Sea', 'type': 'ebsa'},
#   {'id': 181, 'name': 'Russia: North Pacific', 'type': 'eez'},
#   {'id': 499, 'name': 'Caracol/Ft. LibertÅ/Monte Cristi', 'type': 'ebsa'},
#   {'id': 425, 'name': 'Cordillera Malpelo', 'type': 'ebsa'},
#   {'id': 340, 'name': 'Mozambique Channel', 'type': 'ebsa'},
#   {'id': 43, 'name': 'Cuba', 'type': 'eez'},
#   {'id': 498,
#    'name': 'Iles Eparses (part of the Mozambique Channel)',
#    'type': 'ebsa'},
#   {'id': 367, 'name': 'Due South of Great Australian Bight', 'type': 'ebsa'},
#   {'id': 482,
#    'name': 'Habitats cÂtiers de la zone nÅritique (Mauritanie)',
#    'type': 'ebsa'},
#   {'id': 259, 'name': 'Canada: all', 'type': 'eez'},
#   {'id': 166, 'name': 'Palau', 'type': 'eez'},
#   {'id': 392,
#    'name': 'Seabird Foraging Zone in the Southern Labrador Sea',
#    'type': 'ebsa'},
#   {'id': 298, 'name': 'Ibiza, Biodiversity and Culture', 'type': 'prot'},
#   {'id': 429,
#    'name': 'EBSA No. 25:  Palau Southwest EBSA (Dims)',
#    'type': 'ebsa'},
#   {'id': 519,
#    'name': "Zone du Projet de CrÅation de l'aire marine protÅgÅe de Kribi-Campo (Cameroon)",
#    'type': 'ebsa'},
#   {'id': 432, 'name': 'Murman Coast and Varanger Fjord', 'type': 'ebsa'},
#   {'id': 522, 'name': 'Ramiros-Palmerinhas (Angola)', 'type': 'ebsa'},
#   {'id': 291, 'name': 'Aldabra Atoll', 'type': 'prot'},
#   {'id': 423, 'name': 'North Aegean', 'type': 'ebsa'},
#   {'id': 112, 'name': 'Japan', 'type': 'eez'},
#   {'id': 254, 'name': 'Vietnam', 'type': 'eez'},
#   {'id': 278, 'name': 'Portugal: all', 'type': 'eez'},
#   {'id': 527,
#    'name': 'Ventilas Hidrotermales de la Cuenca de Guaymas',
#    'type': 'ebsa'},
#   {'id': 345,
#    'name': 'Marginal Ice Zone and Seasonal Ice-Cover Over the Deep Arctic Ocean',
#    'type': 'ebsa'},
#   {'id': 431, 'name': 'CentralHCSUpwelling', 'type': 'ebsa'},
#   {'id': 3, 'name': 'Angola', 'type': 'eez'},
#   {'id': 201, 'name': 'South Pacific', 'type': 'abnj'},
#   {'id': 61, 'name': 'Fiji', 'type': 'eez'},
#   {'id': 176, 'name': 'Qatar', 'type': 'eez'},
#   {'id': 96, 'name': 'Haiti', 'type': 'eez'},
#   {'id': 87, 'name': 'Germany: North Sea', 'type': 'eez'},
#   {'id': 169, 'name': 'Papua New Guinea', 'type': 'eez'},
#   {'id': 388, 'name': 'South of Java Island', 'type': 'ebsa'},
#   {'id': 396, 'name': 'Great Siberian Polynya', 'type': 'ebsa'},
#   {'id': 14, 'name': 'Australia: Heard and McDonald Islands', 'type': 'eez'},
#   {'id': 421, 'name': 'Peru Upwelling Cores', 'type': 'ebsa'},
#   {'id': 188, 'name': 'Saudi Arabia', 'type': 'eez'},
#   {'id': 375, 'name': 'PeruvianHCSUpwelling', 'type': 'ebsa'},
#   {'id': 358, 'name': 'North-eastern Barents-Kara Sea', 'type': 'ebsa'},
#   {'id': 448, 'name': 'Namib Flyway (Namibia)', 'type': 'ebsa'},
#   {'id': 164, 'name': 'Oman', 'type': 'eez'},
#   {'id': 491, 'name': 'EBSA No. 12: Suwarrow National Park', 'type': 'ebsa'},
#   {'id': 344, 'name': 'Nazca and Salas y Gomez', 'type': 'ebsa'},
#   {'id': 476, 'name': 'Natal Bight', 'type': 'ebsa'},
#   {'id': 107, 'name': 'Israel', 'type': 'eez'},
#   {'id': 493, 'name': 'Saba Bank', 'type': 'ebsa'},
#   {'id': 319,
#    'name': 'Lagoons of New Caledonia: Reef Diversity and Associated Ecosystems',
#    'type': 'prot'},
#   {'id': 472, 'name': 'Zanzibar (Unguja) - Saadani', 'type': 'ebsa'},
#   {'id': 530, 'name': '"Ilha s Tinhosa" (Ilha Principe)', 'type': 'ebsa'},
#   {'id': 147, 'name': 'Netherlands: Curaao', 'type': 'eez'},
#   {'id': 221, 'name': 'United Arab Emirates', 'type': 'eez'},
#   {'id': 435,
#    'name': 'EBSA No. 21: Northern New Zealand/South Fiji Basin',
#    'type': 'ebsa'},
#   {'id': 121, 'name': 'Latvia', 'type': 'eez'},
#   {'id': 210, 'name': 'Sweden: North Sea', 'type': 'eez'},
#   {'id': 258, 'name': 'Brazil: all', 'type': 'eez'},
#   {'id': 161, 'name': 'Norway', 'type': 'eez'},
#   {'id': 19, 'name': 'Bangladesh', 'type': 'eez'},
#   {'id': 108, 'name': 'Israel: Red Sea', 'type': 'eez'},
#   {'id': 157, 'name': 'Nigeria', 'type': 'eez'},
#   {'id': 398, 'name': 'Ob-Enisey River Mouth', 'type': 'ebsa'},
#   {'id': 154, 'name': 'New Zealand: Tokelau', 'type': 'eez'},
#   {'id': 215, 'name': 'Tonga', 'type': 'eez'},
#   {'id': 35, 'name': 'Chile', 'type': 'eez'},
#   {'id': 65, 'name': 'France: Clipperton Island', 'type': 'eez'},
#   {'id': 52, 'name': 'East Timor', 'type': 'eez'},
#   {'id': 366,
#    'name': 'North West Mediterranean Pelagic Ecosystem',
#    'type': 'ebsa'},
#   {'id': 317,
#    'name': 'Brazilian Atlantic Islands: Fernando de Noronha and Atol das Rocas Reserves',
#    'type': 'prot'},
#   {'id': 440, 'name': 'Midriff Islands Region, Mexico', 'type': 'ebsa'},
#   {'id': 503, 'name': 'Delta du Saloum (SÅnÅgal)', 'type': 'ebsa'},
#   {'id': 37, 'name': 'China', 'type': 'eez'},
#   {'id': 173, 'name': 'Portugal', 'type': 'eez'},
#   {'id': 85, 'name': 'Georgia', 'type': 'eez'},
#   {'id': 32, 'name': 'Canada: North Atlantic', 'type': 'eez'},
#   {'id': 326, 'name': 'Surtsey', 'type': 'prot'},
#   {'id': 78, 'name': 'France: North Atlantic', 'type': 'eez'},
#   {'id': 306, 'name': 'Ha Long Bay', 'type': 'prot'},
#   {'id': 133, 'name': 'Mexico: North Atlantic', 'type': 'eez'},
#   {'id': 436,
#    'name': 'EBSA No 3: Seamounts of West Norfolk ridge',
#    'type': 'ebsa'},
#   {'id': 289, 'name': 'Everglades National Park', 'type': 'prot'},
#   {'id': 279, 'name': 'Russia: all', 'type': 'eez'},
#   {'id': 308, 'name': 'Belize Barrier Reef Reserve System', 'type': 'prot'},
#   {'id': 150, 'name': 'Netherlands: Sint-Maarten', 'type': 'eez'},
#   {'id': 100, 'name': 'India', 'type': 'eez'},
#   {'id': 420, 'name': 'Coastal Waters of Chukotka', 'type': 'ebsa'},
#   {'id': 443, 'name': 'Northern Adriatic', 'type': 'ebsa'},
#   {'id': 490,
#    'name': 'Yawari Bay (Sierra Leone) (to revise map and come back to plenary)',
#    'type': 'ebsa'},
#   {'id': 130, 'name': 'Marshall Islands', 'type': 'eez'},
#   {'id': 272, 'name': 'Morocco: all', 'type': 'eez'},
#   {'id': 128, 'name': 'Maldives', 'type': 'eez'},
#   {'id': 240, 'name': 'United States: American Samoa', 'type': 'eez'},
#   {'id': 38, 'name': 'Colombia', 'type': 'eez'},
#   {'id': 456,
#    'name': 'Southeast Shoal and Adjacent Areas on the Tail of the Grand Bank',
#    'type': 'ebsa'},
#   {'id': 416,
#    'name': 'EBSA No. 6: Kermadec-Tonga-Louisville Junction',
#    'type': 'ebsa'},
#   {'id': 492, 'name': 'East Broken Ridge Guyot', 'type': 'ebsa'},
#   {'id': 331, 'name': 'Ningaloo Coast', 'type': 'prot'},
#   {'id': 232, 'name': 'United Kingdom: Montserrat', 'type': 'eez'},
#   {'id': 427,
#    'name': 'Shantary islands shelf, Amur and Tugur bays, Russia',
#    'type': 'ebsa'},
#   {'id': 158, 'name': 'North Atlantic', 'type': 'abnj'},
#   {'id': 172, 'name': 'Poland', 'type': 'eez'},
#   {'id': 113,
#    'name': 'Joint Development: Australia - East Timor',
#    'type': 'eez'},
#   {'id': 377, 'name': 'Eastern Caribbean', 'type': 'ebsa'},
#   {'id': 63,
#    'name': 'France: Amsterdam Island and Saint Paul Island',
#    'type': 'eez'},
#   {'id': 9, 'name': 'Australia', 'type': 'eez'},
#   {'id': 183, 'name': 'Saint Kitts and Nevis', 'type': 'eez'},
#   {'id': 260, 'name': 'Chile: all', 'type': 'eez'},
#   {'id': 411,
#    'name': 'Pedro Bank, Southern Channel, and Morant',
#    'type': 'ebsa'},
#   {'id': 445,
#    'name': 'Banco de la Plata y Banco de la Navidad',
#    'type': 'ebsa'},
#   {'id': 184, 'name': 'Saint Lucia', 'type': 'eez'},
#   {'id': 170, 'name': 'Peru', 'type': 'eez'},
#   {'id': 403,
#    'name': 'Coast of Western and Northern Novaya Zemlya',
#    'type': 'ebsa'},
#   {'id': 494, 'name': 'Orange Cone (Namibia/South Africa)', 'type': 'ebsa'},
#   {'id': 55, 'name': 'Egypt: Mediterranean Sea', 'type': 'eez'},
#   {'id': 68, 'name': 'France: French Polynesia', 'type': 'eez'},
#   {'id': 374, 'name': 'Sicilian Channel', 'type': 'ebsa'},
#   {'id': 535, 'name': 'Blue Bay Marine Park, Mauritius', 'type': 'ebsa'},
#   {'id': 88, 'name': 'Ghana', 'type': 'eez'},
#   {'id': 244, 'name': 'United States: Johnston Atoll', 'type': 'eez'},
#   {'id': 118, 'name': 'Kenya', 'type': 'eez'},
#   {'id': 223, 'name': 'United Kingdom: Anguilla', 'type': 'eez'},
#   {'id': 283, 'name': 'United Kingdom: all', 'type': 'eez'},
#   {'id': 300, 'name': 'Shark Bay, Western Australia', 'type': 'prot'},
#   {'id': 217, 'name': 'Tunisia', 'type': 'eez'},
#   {'id': 231, 'name': 'United Kingdom: Jersey', 'type': 'eez'},
#   {'id': 383,
#    'name': 'EBSA No. 5:  Kadavu and the Southern Lau Region',
#    'type': 'ebsa'},
#   {'id': 212, 'name': 'Tanzania', 'type': 'eez'},
#   {'id': 353,
#    'name': 'EBSA No. 18: Western South Pacific High Aragonite Saturation State Zone',
#    'type': 'ebsa'},
#   {'id': 328, 'name': 'Phoenix Islands Protected Area', 'type': 'prot'},
#   {'id': 256, 'name': 'Antarctica: all', 'type': 'eez'},
#   {'id': 216, 'name': 'Trinidad and Tobago', 'type': 'eez'},
#   {'id': 263, 'name': 'Ecuador: all', 'type': 'eez'},
#   {'id': 202, 'name': 'Southern Ocean', 'type': 'abnj'},
#   {'id': 266, 'name': 'Germany: all', 'type': 'eez'},
#   {'id': 144, 'name': 'Netherlands', 'type': 'eez'},
#   {'id': 453,
#    'name': 'EBSA No: 22: Taveuni and Ringgold Islands',
#    'type': 'ebsa'},
#   {'id': 7, 'name': 'Arctic Ocean', 'type': 'abnj'},
#   {'id': 195, 'name': 'Somalia', 'type': 'eez'},
#   {'id': 129, 'name': 'Malta', 'type': 'eez'},
#   {'id': 8, 'name': 'Argentina', 'type': 'eez'},
#   {'id': 483, 'name': 'Archipel de Bijagos (Guinea-Bissau)', 'type': 'ebsa'},
#   {'id': 305, 'name': 'Tubbataha Reefs Natural Park', 'type': 'prot'},
#   {'id': 80, 'name': 'France: Runion', 'type': 'eez'},
#   {'id': 318,
#    'name': 'Natural System of Wrangel Island Reserve',
#    'type': 'prot'},
#   {'id': 312, 'name': 'New Zealand Sub-Antarctic Islands', 'type': 'prot'},
#   {'id': 179, 'name': 'Russia: Baltic Sea', 'type': 'eez'},
#   {'id': 470,
#    'name': 'Upper Gulf of California Region, Mexico',
#    'type': 'ebsa'}]}

# %% [markdown]
# # Get geo and build data structure
# Here, we loop through the OBIS Areas inventory, build out properties aligned with the target specification, retrieve geometry from the OBIS Geoserver, and package up a GeoJSON feature collection. I hard coded the CRS based on the source for convenience and should probably come back to that at some point.
#
# In the new process we are developing, we apply source processing logic at the PostgreSQL end of this to build a common data model across all sources for at least one purpose in building a large place name lookup index. There will be other purposes for these data requiring different synthesis logic. In this case, there are very few properties to mess with, and they can all be put immediately into the convention we are evolving:
#
# * feature_id - using URN-like syntax, we specify the source context ("OBIS_Areas" in this case) along with an identifier that is unique, reasonably persistent within the source context, and significant in being linkable to associated information
# * feature_name - meaningful name of the feature that will be used in lookup and labeling
# * feature_class - simple string for categorizing the features within the SFR context (needs to be richer and backed by ontology in future)
# * feature_geometry - whatever the geometry is for the feature including its CRS specification

# %%
newOBISAreas = []
for index,obisArea in enumerate(obisAreasInventory["results"]):
    properties = {}
    properties["feature_id"] = "OBIS_Areas:"+str(obisArea["id"])
    properties["feature_name"] = obisArea["name"]
    properties["feature_class"] = codeList["Area Types"][obisArea["type"]]
    properties["getFeatureURL"] = wfsGetFeatureURLStub.replace("<Literal></Literal>","<Literal>"+str(obisArea["id"])+"</Literal>")
    
    areaFeature = requests.get(properties["getFeatureURL"]).json()
    
    if len(areaFeature["features"]) != 1 :
        display (properties)
    else:
        newOBISAreas.append(Feature(geometry=areaFeature["features"][0]["geometry"], properties=properties))

crs = {"type": "EPSG","properties": {"code": "4326"}}
obisAreasCollection = FeatureCollection(newOBISAreas, crs=crs)
# Out:
# {'feature_class': 'Ocean Biogeographic Information System',
#  'feature_id': 'OBIS_Areas:286',
#  'feature_name': 'OBIS',
#  'getFeatureURL': 'http://iobis.org/geoserver/OBIS/ows?service=WFS&version=1.0.0&request=GetFeature&typeName=OBIS:areas&maxFeatures=1&outputFormat=json&filter=<PropertyIsEqualTo><PropertyName>gid</PropertyName><Literal>286</Literal></PropertyIsEqualTo>'}

# %% [markdown]
# # Output file for upload
# Our pattern so far has been to build a file for a processed data source and then load those up via the user interface into GC2's PostgreSQL. There is no other bulk upload method, and record by record loads via the SQL API have either failed or been ridiculously slow. However, we do need to stash these files back on the ScienceBase source item. For another project, we are working on getting programmatic access to official USGS CHS S3 bucket space. Once we have that nailed down, we should come back at these processes and build that in to anything where we need file storage. For now, this outputs a local file that gets uploaded to ScienceBase (because I've gotten frustrated with the vagaries of doing that over the sbAPI as well).

# %%
with open("OBISAreas.geojson", "w") as outfile:
    geojson.dump(obisAreasCollection, outfile)
